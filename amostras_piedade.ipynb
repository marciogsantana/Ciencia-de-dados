# %% [markdown]
# <a href="https://colab.research.google.com/github/marciogsantana/Ciencia-de-dados/blob/main/amostras_piedade.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
filial = pd.read_csv('importacao_filial.csv', sep=';')

# %%
filial
# Out:
#      PRODUTOR  LINHA  ... INIBIDOR MICROBIOLOGICO  PONTO DE CONGELAMENTO
# 0    00001/01      3  ...                     NaN                    NaN
# 1    00002/01      3  ...                     NaN                    NaN
# 2    00005/01      7  ...                     NaN                    NaN
# 3    00007/01      3  ...                     NaN                    NaN
# 4    00009/01     12  ...                     NaN                    NaN
# ..        ...    ...  ...                     ...                    ...
# 369    818/01     33  ...                     NaN                    NaN
# 370    828/01     11  ...                     NaN                    NaN
# 371    918/01      8  ...                     NaN                    NaN
# 372    919/01     19  ...                     NaN                    NaN
# 373    921/01     41  ...                     NaN                    NaN
#
# [374 rows x 19 columns]

# %%
magis = pd.read_excel('planilha_magis.xlsx')

# %%
magis
# Out:
#      Código                                Nome  ... Cartão do Produtor       NIRF
# 0         1                CUSTODIO LUCAS RAMOS  ...                NaN   22173226
# 1        36            JESUS DONIZETE DE MORAIS  ...                NaN   49526367
# 2        37                JOSE LUCIO PARREIRAS  ...                NaN        NaN
# 3        46             MARCIO ANTONIO DE FARIA  ...                NaN        NaN
# 4        58              NEY ROBSON DE OLIVEIRA  ...                NaN        NaN
# ..      ...                                 ...  ...                ...        ...
# 407    6812            AGNALDO DE MORAIS BORGES  ...                NaN  2773774-8
# 408    6813            PEDRO ANDRE DE OLIVEIRA   ...                NaN   27737861
# 409    6814  GERALDO RODRIGUES DE SOUZA DUARTE   ...                NaN   95149546
# 410    6815            LESLEI ANTONIO DE SOUZA   ...                NaN        NaN
# ...

# %%
lista_codigo_magis = []
lista_cpf_magis = []
for index, row in magis.iterrows(): 
  codigo = (row['Código'])
  lista_codigo_magis.append(codigo)
  cpf = (row['CPF'])
  lista_cpf_magis.append(cpf)

# %%
lista_codigo_magis
# Out:
# [1,
#  36,
#  37,
#  46,
#  58,
#  60,
#  62,
#  63,
#  66,
#  1002,
#  1004,
#  1005,
#  1006,
#  1008,
#  1010,
#  1011,
#  1012,
#  1013,
#  1014,
#  1015,
#  1016,
#  1018,
#  1020,
#  1021,
#  1022,
#  1024,
#  1025,
#  1026,
#  1027,
#  1028,
#  1029,
#  1033,
#  1055,
#  1059,
#  1065,
#  1069,
#  1100,
#  1102,
#  1105,
#  1106,
#  1208,
#  1215,
#  1228,
#  1229,
#  1230,
#  5000,
#  5001,
#  5003,
#  5005,
#  5007,
#  5008,
#  5009,
#  5010,
#  5011,
#  5012,
#  5013,
#  5015,
#  5016,
#  5017,
#  5018,
#  5020,
#  5021,
#  5026,
#  5027,
#  5032,
#  5033,
#  5037,
#  5041,
#  5046,
#  5048,
#  5050,
#  5051,
#  5053,
#  5054,
#  5055,
#  5060,
#  5062,
#  5068,
#  5069,
#  5071,
#  5072,
#  5074,
#  5076,
#  5082,
#  5084,
#  5085,
#  5094,
#  5097,
#  5101,
#  5103,
#  5104,
#  5106,
#  5107,
#  5109,
#  5111,
#  5113,
#  5128,
#  5132,
#  5134,
#  5136,
#  5139,
#  5140,
#  5149,
#  5153,
#  5158,
#  5159,
#  5160,
#  5162,
#  5173,
#  5174,
#  5177,
#  5178,
#  5182,
# ...

# %%
lista_cpf_magis
# Out:
# ['391.612.696-20',
#  '757.579.826-91',
#  '741.031.646-20',
#  '516.277.366-20',
#  '049.894.806-43',
#  '526.585.206-97',
#  '408.429.246-04',
#  '264.904.986-34',
#  '059.739.246-37',
#  '544.298.546-53',
#  '229.390.836-49',
#  '052.272.116-80',
#  '140.117.946-00',
#  '185.672.156-68',
#  '020.285.309-87',
#  '813.406.566-04',
#  '814.550.706-53',
#  '378.409.596-87',
#  '222.139.456-91',
#  '138.522.216-68',
#  '027.885.806-65',
#  '298.157.976-20',
#  '499.351.606-10',
#  '042.158.936-15',
#  '029.406.346-37',
#  '051.134.156-34',
#  '360.523.881-53',
#  '001.162.836-70',
#  '425.560.586-68',
#  '055.308.226-49',
#  '337.354.416-53',
#  '043.578.336-04',
#  '131.621.016-20',
#  '373.746.216-04',
#  '264.393.876-34',
#  '596.421.576-91',
#  '268.882.626-34',
#  '455.579.186-04',
#  '428.181.096-04',
#  '764.539.526-53',
#  '062.681.426-08',
#  '079.071.466-31',
#  '839.761.086-34',
#  '526.595.696-49',
#  '373.734.986-04',
#  '995.506.011-53',
#  '639.502.946-00',
# ...
